# %% [markdown]
# # Networks
#
# ![](images/network1.png)
#
# ## Social Newtorks
#
# * Nodes = People
# * Edges = Relationship
#
# ![](images/network2.png)
#
# ## Transportation and mobility networks
#
#
# ![](images/network3.png)
#
# ## Informationy networks
#
#
# ![](images/network4.png)
#
# ## Biological networks
#
#
# ![](images/network5.png)
#
# ## More Examples
#
# * Financial networks
# * co authorship networks
# * trade networks
# * citation networks
#
# ## Networks Applciations
#
# Networks are everywhere, but what can we do with them?
#
# ### Email network
#
# * Is a rumor likely to spread in this netwoprk?
# * Who are the most influential people in this prganization?
#
# ![](images/network6.png)
#
# ### Club network
#
# * Is this club likely to split into two groups?
# * If so, which nodes will go to which group?
#
# ![](images/network7.png)
#
# ### Transportation network
#
# * Which airports are at highest risk for virus spreading?
# * Are some parts of the world more difficult to reach?
#
# ![](images/network8.png)
#
# # Summary
#
# * Many complex structures can be modeled by networks.
# * Studying the structure of a network can allows us to answer questions about complex phenomena
