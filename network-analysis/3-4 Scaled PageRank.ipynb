# %% [markdown]
# # Scaled Page Rank
#
# ## How to interprete PageRank
#
# The PageRank of a node at step *k* is the probability that ta **random walker** lands on the node after taking *k* steps.
#
# * **Random walk of k steps:** Start on a random node. Then choose an ougroing edge at random and follow it to the next node. Repeat *k* times.
#
# Example: a random walk of 5 steps
#
#
#
# Step 1: Choose a random node, then
# choose a random outgoing edge.then follow the edge to the next node.
#
# ![](images/3-4.1.png)
# ![](images/3-4.2.png)
# ![](images/3-4.3.png)
#
# Step 2 Choose a random outgoing edge and follow it.
#
# ![](images/3-4.4.png)
#
# Step 3 Choose a random outgoing edge and follow it.
#
# ![](images/3-4.5.png)
#
#
# Step 4 Choose a random outgoing edge and follow it.
#
# ![](images/3-4.6.png)
#
# Step 5 Choose a random outgoing edge and follow it.
#
# ![](images/3-4.7.png)
#
# ![](images/3-4.8.png)
#
#
#
# ## PageRank Problem
#
# ![](images/3-4.9.png)
#
# For a large enough *k*: F and G wach have PageRank of 1/2 and all the other node have PageRank 0.
#
# Why? Imagine a random walk on this network. Whenever the walk lands on F or G, it is "stuck" on F and G
#
# To fix this, we can use 'damping parameter' $\alpha$
#
# * **Random walkl of** $k$ **steps with damping parameter** $\alpha$ start on a random node. then
#
# * With probability $\alpha$: Choose an outgoing edge at random and follow it to the next node.
# * With probability $1-\alpha$: Choose a node at random and go to it.
#
# and repeat K times
#
# THe random walk is no longer 'stuck' on nodes F and G
#
#
# ## Scaled PageRank
#
# THe **Scaled PageRank** of $k$  steps and damping factor $\alpha$ of a node $n$ is the probability that a random walk wiht damping factor $\alpha$ lands on a $n$ after $k$ steps
#
# * FOr most networks, as $k$ gets larger, Scaled Pagerank converges to a unique value, which depends on $\alpha$.
#
# ![](images/3-4.10.png)
#
# You can use NetworkX function `pagerank(G,alpha=0.8)` to compute Scaled pageRank of network G with damping paraemter alpha.
#
#
# # Summary
# ![](images/3-4.11.png)
